# %%
import pandas as pd

train = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
type(train)
# Out:
# pandas.core.frame.DataFrame

# %%
train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
type(train.dtypes)
# Out:
# pandas.core.series.Series

# %%
type(train.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
train["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
train["Age"][2:5]
# Out:
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
train["Age"][::-1]
# Out:
# 890    32.0
# 889    26.0
# 888     NaN
# 887    19.0
# 886    27.0
#        ...
# 4      35.0
# 3      35.0
# 2      26.0
# 1      38.0
# 0      22.0
# Name: Age, Length: 891, dtype: float64

# %%
train["Age"][-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py:385, in RangeIndex.get_loc(self, key, method, tolerance)
#     384 try:
# --> 385     return self._range.index(new_key)
#     386 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [11], line 1
# ----> 1 train["Age"][-1]
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
# ...

# %%
train["Age"][::5]
# Out:
# 0      22.0
# 5       NaN
# 10      4.0
# 15     55.0
# 20     35.0
#        ...
# 870    26.0
# 875    15.0
# 880    25.0
# 885    39.0
# 890    32.0
# Name: Age, Length: 179, dtype: float64

# %%
train["Age"][train["Age"] == "NaN"]
# Out:
# Series([], Name: Age, dtype: float64)

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
train.dtypes == "object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
train.dtypes[train.dtypes == "object"]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
train.dtypes[train.dtypes == "object"].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# # Categorical Data extracted

# %%
cat = train[train.dtypes[train.dtypes == "object"].index]

# %%
cat
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
cat.describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
train[["Name","Cabin"] ]
# Out:
#                                                   Name Cabin
# 0                              Braund, Mr. Owen Harris   NaN
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...   C85
# 2                               Heikkinen, Miss. Laina   NaN
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123
# 4                             Allen, Mr. William Henry   NaN
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas   NaN
# 887                       Graham, Miss. Margaret Edith   B42
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  C148
# 890                                Dooley, Mr. Patrick   NaN
#
# [891 rows x 2 columns]

# %%
type(train[["Name","Cabin"] ])
# Out:
# pandas.core.frame.DataFrame

# %%
train["Age"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
import numpy as np

age_null = np.where(train["Age"].isnull())

# %%
train[train["Age"].isnull() == True]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
age_null
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154, 158, 159, 166, 168, 176, 180, 181, 185, 186,
#         196, 198, 201, 214, 223, 229, 235, 240, 241, 250, 256, 260, 264,
#         270, 274, 277, 284, 295, 298, 300, 301, 303, 304, 306, 324, 330,
#         334, 335, 347, 351, 354, 358, 359, 364, 367, 368, 375, 384, 388,
#         409, 410, 411, 413, 415, 420, 425, 428, 431, 444, 451, 454, 457,
#         459, 464, 466, 468, 470, 475, 481, 485, 490, 495, 497, 502, 507,
#         511, 517, 522, 524, 527, 531, 533, 538, 547, 552, 557, 560, 563,
#         564, 568, 573, 578, 584, 589, 593, 596, 598, 601, 602, 611, 612,
#         613, 629, 633, 639, 643, 648, 650, 653, 656, 667, 669, 674, 680,
#         692, 697, 709, 711, 718, 727, 732, 738, 739, 740, 760, 766, 768,
#         773, 776, 778, 783, 790, 792, 793, 815, 825, 826, 828, 832, 837,
# ...

# %% [markdown]
# # iloc

# %%
train.iloc[age_null]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
train.iloc[5]
# Out:
# PassengerId                   6
# Survived                      0
# Pclass                        3
# Name           Moran, Mr. James
# Sex                        male
# Age                         NaN
# SibSp                         0
# Parch                         0
# Ticket                   330877
# Fare                     8.4583
# Cabin                       NaN
# Embarked                      Q
# Name: 5, dtype: object

# %%
type(train.iloc[5])
# Out:
# pandas.core.series.Series

# %%
train.iloc[[1,3,4,5]]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch    Ticket     Fare Cabin Embarked
# 1      0  PC 17599  71.2833   C85        C
# 3      0    113803  53.1000  C123        S
# 4      0    373450   8.0500   NaN        S
# 5      0    330877   8.4583   NaN        Q

# %%
t = train.iloc[0: 100]

# %%
t
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 95           96         0       3
# 96           97         0       1
# 97           98         1       1
# 98           99         1       2
# 99          100         0       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# ..                                                ...     ...   ...    ...
# ...

# %%
max(train["Fare"])
# Out:
# 512.3292

# %%
train.iloc[[max(train["Fare"])]]
# Out:
#      PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 512          513         1       1  McGough, Mr. James Robert  male  36.0
#
#      SibSp  Parch    Ticket     Fare Cabin Embarked
# 512      0      0  PC 17473  26.2875   E25        S

# %% [markdown]
# # iloc requires location/position

# %% [markdown]
# # Index of the max  fare

# %%
train.iloc[np.where(train["Fare"] == max(train["Fare"]))]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
train.iloc[np.where(train["Fare"] == max(train["Fare"]))]["Name"]
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
train.iloc[np.where(train["Fare"] == (train["Fare"].max()))]["Name"]
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %% [markdown]
# # Age 24

# %%
train[train["Age"] == 24.0]["Name"]
# Out:
# 89                                Celotti, Mr. Francesco
# 118                             Baxter, Mr. Quigg Edmond
# 127                            Madsen, Mr. Fridtjof Arne
# 139                                   Giglio, Mr. Victor
# 142    Hakkarainen, Mrs. Pekka Pietari (Elin Matilda ...
# 199               Yrois, Miss. Henriette ("Mrs Harbeck")
# 210                                       Ali, Mr. Ahmed
# 234                    Leyson, Mr. Robert William Norman
# 247                      Hamalainen, Mrs. William (Anna)
# 293                                  Haas, Miss. Aloisia
# 294                                     Mineff, Mr. Ivan
# 310                       Hays, Miss. Margaret Bechstein
# 316                  Kantor, Mrs. Sinai (Miriam Sternin)
# 341                       Fortune, Miss. Alice Elizabeth
# 345                        Brown, Miss. Amelia "Mildred"
# 369                        Aubart, Mme. Leontine Pauline
# ...

# %%
train[train["Age"] == train["Age"].min()]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander  male
#
#       Age  SibSp  Parch Ticket    Fare Cabin Embarked
# 803  0.42      0      1   2625  8.5167   NaN        C

# %%
train[train["Age"] == train["Age"].min()][["Name","Age"]]
# Out:
#                                 Name   Age
# 803  Thomas, Master. Assad Alexander  0.42

# %% [markdown]
# # Persons age who's cabin is Nan

# %%
train["Cabin"].isnull()
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Cabin, Length: 891, dtype: bool

# %%
train.iloc[np.where(train["Cabin"].isnull())]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
train[train["Cabin"].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
train[train["Cabin"].isnull()][["Age", "Cabin"]]
# Out:
#       Age Cabin
# 0    22.0   NaN
# 2    26.0   NaN
# 4    35.0   NaN
# 5     NaN   NaN
# 7     2.0   NaN
# ..    ...   ...
# 884  25.0   NaN
# 885  39.0   NaN
# 886  27.0   NaN
# 888   NaN   NaN
# 890  32.0   NaN
#
# [687 rows x 2 columns]

# %%
train.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# # Name of the Male passengers who survided

# %%
train[train["Survived"] == 1 ][train["Sex"] == "male"]["Name"]
# Out:
# C:\Users\Tanjina\AppData\Local\Temp\ipykernel_17028\3214431261.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   train[train["Survived"] == 1 ][train["Sex"] == "male"]["Name"]
# 17        Williams, Mr. Charles Eugene
# 21               Beesley, Mr. Lawrence
# 23        Sloper, Mr. William Thompson
# 36                    Mamee, Mr. Hanna
# 55                   Woolner, Mr. Hugh
#                     ...
# 838                    Chip, Mr. Chang
# 839               Marechal, Mr. Pierre
# 857             Daly, Mr. Peter Denis
# 869    Johnson, Master. Harold Theodor
# 889              Behr, Mr. Karl Howell
# Name: Name, Length: 109, dtype: object

# %%
train[(train["Survived"] == 1) & (train["Sex"] == "male")]["Name"]
# Out:
# 17        Williams, Mr. Charles Eugene
# 21               Beesley, Mr. Lawrence
# 23        Sloper, Mr. William Thompson
# 36                    Mamee, Mr. Hanna
# 55                   Woolner, Mr. Hugh
#                     ...
# 838                    Chip, Mr. Chang
# 839               Marechal, Mr. Pierre
# 857             Daly, Mr. Peter Denis
# 869    Johnson, Master. Harold Theodor
# 889              Behr, Mr. Karl Howell
# Name: Name, Length: 109, dtype: object

# %%
#  Adding a new column to the existing column
train["New_Column"] = "Pro"

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Conversion

# %%
 #list to series conversion
l = [1,2,3,4,5]
pd.Series(l)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# Dict to Series Conversion
d = {"key": "Pro", "title": "Sid"}

# %%
pd.DataFrame(d, index = ['key', 'title'])
# Out:
#        key title
# key    Pro   Sid
# title  Pro   Sid

# %%
pd.Series(d)
# Out:
# key      Pro
# title    Sid
# dtype: object

# %%
# Array to Series conversion

arr = np.random.randn(4)
pd.DataFrame(arr)
# Out:
#           0
# 0 -1.542784
# 1 -1.187490
# 2 -1.941708
# 3 -1.387196

# %%
pd.Series(arr)
# Out:
# 0   -1.542784
# 1   -1.187490
# 2   -1.941708
# 3   -1.387196
# dtype: float64

# %%
s = pd.Series(np.array([1,2,3,4]), index = ['a','b','c','d'])

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int32

# %%
s["a"]
# Out:
# 1

# %%
s.iloc["a"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [64], line 1
# ----> 1 s.iloc["a"]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1520, in _iLocIndexer._getitem_axis(self, key, axis)
#    1518 key = item_from_zerodim(key)
#    1519 if not is_integer(key):
# -> 1520     raise TypeError("Cannot index by location index with a non-integer key")
#    1522 # validate the location
#    1523 self._validate_integer(key, axis)
#
# TypeError: Cannot index by location index with a non-integer key

# %% [markdown]
# # iloc = integer location,  loc = location
#
# iloc takes default indexes like 1,2,3,...
# loc takes named indexes like a,b,..,54,554

# %%
s.loc["a"]
# Out:
# 1

# %%
s1 = pd.Series(np.array([1,2,3]), index = [11,22,33])

# %%
s1
# Out:
# 11    1
# 22    2
# 33    3
# dtype: int32

# %%
s1.iloc[22]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [68], line 1
# ----> 1 s1.iloc[22]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1523, in _iLocIndexer._getitem_axis(self, key, axis)
#    1520     raise TypeError("Cannot index by location index with a non-integer key")
#    1522 # validate the location
# -> 1523 self._validate_integer(key, axis)
#    1525 return self.obj._ixs(key, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1455, in _iLocIndexer._validate_integer(self, key, axis)
#    1453 len_axis = len(self.obj._get_axis(axis))
# ...

# %%
s1.loc[22]
# Out:
# 2

# %%
np.random.randint(3,6,(4,5))
# Out:
# array([[5, 4, 4, 4, 4],
#        [3, 3, 4, 3, 4],
#        [5, 4, 5, 4, 5],
#        [5, 3, 5, 3, 4]])

# %%
pd.DataFrame(np.random.randint(3,6,(4,5)))
# Out:
#    0  1  2  3  4
# 0  5  5  4  5  3
# 1  3  4  4  4  5
# 2  4  5  3  3  5
# 3  5  5  3  3  3

# %%
df = pd.DataFrame(np.random.randint(1,9,(4,5)), index = ['a', 'b', 'c','d'], columns = ['x','y','z','u','v'])

# %%
df
# Out:
#    x  y  z  u  v
# a  3  2  2  5  3
# b  1  3  4  5  4
# c  4  2  6  5  1
# d  7  1  4  3  5

# %%
df.loc[['c','d'],['z','u']]
# Out:
#    z  u
# c  6  5
# d  4  3

# %%
df["z"]["c"]
# Out:
# 6

# %%
 df["new"] = df['x'] + df.y

# %%
df
# Out:
#    x  y  z  u  v  new
# a  3  2  2  5  3    5
# b  1  3  4  5  4    4
# c  4  2  6  5  1    6
# d  7  1  4  3  5    8

# %%
df.drop("d")
# Out:
#    x  y  z  u  v  new
# a  3  2  2  5  3    5
# b  1  3  4  5  4    4
# c  4  2  6  5  1    6

# %%
df.drop("v", axis =1, inplace=True)

# %%
df
# Out:
#    x  y  z  u  new
# a  3  2  2  5    5
# b  1  3  4  5    4
# c  4  2  6  5    6
# d  7  1  4  3    8

# %%
np.random.seed(23)
df = pd.DataFrame(np.random.randn(4,5), index = ['a', 'b', 'c','d'], columns = ['x','y','z','u','v'])

# %%
df
# Out:
#           x         y         z         u         v
# a  0.666988  0.025813 -0.777619  0.948634  0.701672
# b -1.051082 -0.367548 -1.137460 -1.322148  1.772258
# c -0.347459  0.670140  0.322272  0.060343 -1.043450
# d -1.009942  0.441736  1.128877 -1.838068 -0.938769

# %% [markdown]
# # Negative values in df

# %%
df.values[df.values<0]
# Out:
# array([-0.77761941, -1.05108156, -0.36754812, -1.13745969, -1.32214752,
#        -0.34745899, -1.04345   , -1.00994188, -1.83806777, -0.93876863])

# %%
df.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
df.columns
# Out:
# Index(['x', 'y', 'z', 'u', 'v'], dtype='object')

# %% [markdown]
# # HW: printing negative values and their index

# %%
for i in df.index:
    for j in df.columns:
        if df.loc[i,j]<0:
            print(i, j, df.loc[i,j])
# Out:
# a z -0.7776194131918178
# b x -1.0510815639071178
# b y -0.3675481161171661
# b z -1.1374596907250272
# b u -1.3221475225908594
# c x -0.34745899102186334
# c v -1.0434500017467254
# d x -1.0099418765878465
# d u -1.8380677677579502
# d v -0.9387686311201282

# %% [markdown]
# # nan value dropna, fillna,

# %%
d = {"key1": [1,2,np.nan, 7], "key2": ["pro", 3 ,4,7], "key3": [9,np.nan, np.nan, 7]}
df= pd.DataFrame(d)

# %%
df
# Out:
#    key1 key2  key3
# 0   1.0  pro   9.0
# 1   2.0    3   NaN
# 2   NaN    4   NaN
# 3   7.0    7   7.0

# %%
df.dropna()
# Out:
#    key1 key2  key3
# 0   1.0  pro   9.0
# 3   7.0    7   7.0

# %%
df.dropna(axis= 1)
# Out:
#   key2
# 0  pro
# 1    3
# 2    4
# 3    7

# %%
df.dropna(thresh=2)
# Out:
#    key1 key2  key3
# 0   1.0  pro   9.0
# 1   2.0    3   NaN
# 3   7.0    7   7.0

# %%
df.dropna(thresh=3)
# Out:
#    key1 key2  key3
# 0   1.0  pro   9.0
# 3   7.0    7   7.0

# %%
df.dropna(thresh=1)
# Out:
#    key1 key2  key3
# 0   1.0  pro   9.0
# 1   2.0    3   NaN
# 2   NaN    4   NaN
# 3   7.0    7   7.0

# %%
df.fillna(9999)
# Out:
#      key1 key2    key3
# 0     1.0  pro     9.0
# 1     2.0    3  9999.0
# 2  9999.0    4  9999.0
# 3     7.0    7     7.0

# %%
df
# Out:
#    key1 key2  key3
# 0   1.0  pro   9.0
# 1   2.0    3   NaN
# 2   NaN    4   NaN
# 3   7.0    7   7.0

# %%
df.fillna(df["key1"].mean())
# Out:
#        key1 key2      key3
# 0  1.000000  pro  9.000000
# 1  2.000000    3  3.333333
# 2  3.333333    4  3.333333
# 3  7.000000    7  7.000000

# %% [markdown]
# # group by

# %%
d1 = {"name": ["pro", "sam", "sak",'sam'], "email":["pro@gmail.com", "sam@gmail.com","sak@gmail.com", 'sam@gmail.com'], "salary": [50,20,10, 100]}

# %%
d1
# Out:
# {'name': ['pro', 'sam', 'sak', 'sam'],
#  'email': ['pro@gmail.com', 'sam@gmail.com', 'sak@gmail.com', 'sam@gmail.com'],
#  'salary': [50, 20, 10, 100]}

# %%
df = pd.DataFrame(d1)

# %%
df
# Out:
#   name          email  salary
# 0  pro  pro@gmail.com      50
# 1  sam  sam@gmail.com      20
# 2  sak  sak@gmail.com      10
# 3  sam  sam@gmail.com     100

# %%
df.groupby("name").mean()
# Out:
#       salary
# name
# pro     50.0
# sak     10.0
# sam     60.0

# %%
df.groupby("email").mean()
# Out:
#                salary
# email
# pro@gmail.com    50.0
# sak@gmail.com    10.0
# sam@gmail.com    60.0

# %%
df.groupby("name").sum()
# Out:
#       salary
# name
# pro       50
# sak       10
# sam      120

# %%
df.groupby("name").describe()
# Out:
#      salary
#       count  mean        std   min   25%   50%   75%    max
# name
# pro     1.0  50.0        NaN  50.0  50.0  50.0  50.0   50.0
# sak     1.0  10.0        NaN  10.0  10.0  10.0  10.0   10.0
# sam     2.0  60.0  56.568542  20.0  40.0  60.0  80.0  100.0

# %%
df.groupby("name").describe().loc["pro"]
# Out:
# salary  count     1.0
#         mean     50.0
#         std       NaN
#         min      50.0
#         25%      50.0
#         50%      50.0
#         75%      50.0
#         max      50.0
# Name: pro, dtype: float64

# %%
df.groupby("name").describe().loc["pro"]["salary"]["mean"]
# Out:
# 50.0

# %%
df.groupby("name").describe().loc["pro"][1]
# Out:
# 50.0

# %%
df.groupby("name").describe().T
# Out:
# name           pro   sak         sam
# salary count   1.0   1.0    2.000000
#        mean   50.0  10.0   60.000000
#        std     NaN   NaN   56.568542
#        min    50.0  10.0   20.000000
#        25%    50.0  10.0   40.000000
#        50%    50.0  10.0   60.000000
#        75%    50.0  10.0   80.000000
#        max    50.0  10.0  100.000000

# %%
df.groupby("name").describe()
# Out:
#      salary
#       count  mean        std   min   25%   50%   75%    max
# name
# pro     1.0  50.0        NaN  50.0  50.0  50.0  50.0   50.0
# sak     1.0  10.0        NaN  10.0  10.0  10.0  10.0   10.0
# sam     2.0  60.0  56.568542  20.0  40.0  60.0  80.0  100.0

# %% [markdown]
# # Concat

# %%
a1 = np.random.randn(2,4)
a2 = np.random.randn(2,4)
a3 = np.random.randn(2,4)

# %%
df1 = pd.DataFrame(a1, columns=["A","B","C","D"], index = [0,1])
df2 = pd.DataFrame(a2, columns=["A","B","C","D"], index = [0,1])
df3 = pd.DataFrame(a3, columns=["A","B","C","D"], index = [0,1])

# %%
df1
# Out:
#           A         B         C         D
# 0 -0.201841  1.045371  0.538162  0.812119
# 1  0.241106 -0.952510 -0.136267  1.267248

# %%
df2
# Out:
#           A         B         C         D
# 0  0.173634 -1.223255  1.415320  0.457711
# 1  0.728876  1.968435 -0.547788 -0.679418

# %%
df3
# Out:
#           A         B         C         D
# 0 -2.506230  0.146960  0.606195 -0.022539
# 1  0.013422  0.935945  0.420623  0.411620

# %%
df4 = pd.concat([df1, df2, df3])
df4
# Out:
#           A         B         C         D
# 0 -0.201841  1.045371  0.538162  0.812119
# 1  0.241106 -0.952510 -0.136267  1.267248
# 0  0.173634 -1.223255  1.415320  0.457711
# 1  0.728876  1.968435 -0.547788 -0.679418
# 0 -2.506230  0.146960  0.606195 -0.022539
# 1  0.013422  0.935945  0.420623  0.411620

# %%
df5 = pd.concat([df1, df2, df3], axis = 1)
df5
# Out:
#           A         B         C         D         A         B         C  \
# 0 -0.201841  1.045371  0.538162  0.812119  0.173634 -1.223255  1.415320
# 1  0.241106 -0.952510 -0.136267  1.267248  0.728876  1.968435 -0.547788
#
#           D         A         B         C         D
# 0  0.457711 -2.506230  0.146960  0.606195 -0.022539
# 1 -0.679418  0.013422  0.935945  0.420623  0.411620

# %%
df4.loc[0]
# Out:
#           A         B         C         D
# 0 -0.201841  1.045371  0.538162  0.812119
# 0  0.173634 -1.223255  1.415320  0.457711
# 0 -2.506230  0.146960  0.606195 -0.022539

# %%
df5['A']
# Out:
#           A         A         A
# 0 -0.201841  0.173634 -2.506230
# 1  0.241106  0.728876  0.013422

# %% [markdown]
# # Merge

# %%
np.random.seed(23)
a1 = np.random.randn(2,4)
np.random.seed(23)
a2 = np.random.randn(2,4)

df11 = pd.DataFrame(a1, columns=["A","B","C","D"], index = [0,1])
df22 = pd.DataFrame(a2, columns=["A","B","C","D"], index = [0,1])

# %%
df11
# Out:
#           A         B         C         D
# 0  0.666988  0.025813 -0.777619  0.948634
# 1  0.701672 -1.051082 -0.367548 -1.137460

# %%
df22
# Out:
#           A         B         C         D
# 0  0.666988  0.025813 -0.777619  0.948634
# 1  0.701672 -1.051082 -0.367548 -1.137460

# %%
df1122 = pd.merge(df11,df22, on = "A")

# %%
df1122
# Out:
#           A       B_x       C_x       D_x       B_y       C_y       D_y
# 0  0.666988  0.025813 -0.777619  0.948634  0.025813 -0.777619  0.948634
# 1  0.701672 -1.051082 -0.367548 -1.137460 -1.051082 -0.367548 -1.137460

# %%
df1 = pd.DataFrame({'key':['K0', 'K8', 'K2', 'K3'],
                 'A': ['A0', 'A1', 'A2', 'A3'],
                 'B': ['B0', 'B1', 'B2', 'B3']
                 }
                )

df2 = pd.DataFrame({'key':['K0', 'K1', 'K2', 'K3'],
                 'C': ['C0', 'C1', 'C2', 'C3'],
                 'D': ['D0', 'D1', 'D2', 'D3']
                 }
                )

# %%
df1
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K8  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
df2
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
pd.merge(df1,df2, on = 'key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K2  A2  B2  C2  D2
# 2  K3  A3  B3  C3  D3

# %%
pd.merge(df1,df2, on = 'key', how = 'left')
# Out:
#   key   A   B    C    D
# 0  K0  A0  B0   C0   D0
# 1  K8  A1  B1  NaN  NaN
# 2  K2  A2  B2   C2   D2
# 3  K3  A3  B3   C3   D3

# %%
pd.merge(df1,df2, on = 'key', how = 'right')
# Out:
#   key    A    B   C   D
# 0  K0   A0   B0  C0  D0
# 1  K1  NaN  NaN  C1  D1
# 2  K2   A2   B2  C2  D2
# 3  K3   A3   B3  C3  D3

# %%
pd.merge(df1,df2, on = 'key', how = 'outer')
# Out:
#   key    A    B    C    D
# 0  K0   A0   B0   C0   D0
# 1  K8   A1   B1  NaN  NaN
# 2  K2   A2   B2   C2   D2
# 3  K3   A3   B3   C3   D3
# 4  K1  NaN  NaN   C1   D1

# %%
df1 = pd.DataFrame({'key1':['K0', 'K0', 'K1', 'K2'],
                    'key2':['K0', 'K1', 'K0', 'K1'],
                 'A': ['A0', 'A1', 'A2', 'A3'],
                 'B': ['B0', 'B1', 'B2', 'B3']
                 }
                )

df2 = pd.DataFrame({'key1':['K0', 'K1','K1', 'K2'],
                    'key2':['K0', 'K0', 'K0', 'K0'],
                 'C': ['C0', 'C1', 'C2', 'C3'],
                 'D': ['D0', 'D1', 'D2', 'D3']
                 }
                )

# %%
df1
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3

# %%
df2
# Out:
#   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K1   K0  C2  D2
# 3   K2   K0  C3  D3

# %%
pd.merge(df1,df2, on = ['key1', 'key2'])
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %% [markdown]
# # JOIN

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                    'B': ['B0', 'B1', 'B2']},
                    index = ['K0', 'K1', 'K2']
                )

df2 = pd.DataFrame({'C': ['C0', 'C1', 'C2'],
                    'D': ['D0', 'D1', 'D2']},
                     index = ['K0', 'K2', 'K3']
                 
                )

# %%
df1
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2

# %%
df2
# Out:
#      C   D
# K0  C0  D0
# K2  C1  D1
# K3  C2  D2

# %%
df1.join(df2)
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C1   D1

# %%
df1.join(df2, how = 'outer')
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C1   D1
# K3  NaN  NaN   C2   D2
